# %%
import pandas as pd 
import os 
import numpy as np
import json

# %%
list_files = [file_ for file_ in os.listdir() if file_.endswith("RESULTS.json")]
json_files = []
for json_file in list_files:
    
    with open(json_file, "r") as f:
        js = json.load(f)
        json_files.append(js)

# %%
json_files[0][0].keys()
# Out:
# dict_keys(['model', 'type_experiment', 'n_trainable_params', 'cl_technique', 'hyperparams', 'experiment_name', 'time', 'dataset_currently_testing', 'dataset_currently_training', 'dataset_wrt_training_datasets', 'target_epochs', 'best_epochs', 'learning_rate', 'batch_size', 'current_num_samples_training', 'cumulative_samples_trained', 'f1_score', 'precision_score', 'recall_score', 'accuracy', 'HATE_f1_score', 'HATE_precision_score', 'HATE_recall_score', 'NoHATE_f1_score', 'NoHATE_precision_score', 'NoHATE_recall_score', 'predictions', 'labels', 'generations', 'unfiltered_outputs'])

# %%
keys_to_exclude = ["predictions", "labels", "generations", "unfiltered_outputs"]

# %%
type(json_files[0][0])
# Out:
# dict

# %%
for time in json_files:
    for d in time:
        for key in keys_to_exclude:
            d.pop(key, None)

# %%
json_files[0][0].keys()
# Out:
# dict_keys(['model', 'type_experiment', 'n_trainable_params', 'cl_technique', 'hyperparams', 'experiment_name', 'time', 'dataset_currently_testing', 'dataset_currently_training', 'dataset_wrt_training_datasets', 'target_epochs', 'best_epochs', 'learning_rate', 'batch_size', 'current_num_samples_training', 'cumulative_samples_trained', 'f1_score', 'precision_score', 'recall_score', 'accuracy', 'HATE_f1_score', 'HATE_precision_score', 'HATE_recall_score', 'NoHATE_f1_score', 'NoHATE_precision_score', 'NoHATE_recall_score'])

# %%
json_files = [item for sublist in json_files for item in sublist]

# %%
len(json_files)
# Out:
# 24

# %%
df = pd.DataFrame(data=json_files, columns=json_files[0].keys())

# %%
df.head()
# Out:
#            model type_experiment  n_trainable_params       cl_technique  \
# 0  diptanu/fBERT            test           109483778  ZERO_SHOT_TESTING
# 1  diptanu/fBERT            test           109483778  ZERO_SHOT_TESTING
# 2  diptanu/fBERT            test           109483778  ZERO_SHOT_TESTING
# 3  diptanu/fBERT            test           109483778  ZERO_SHOT_TESTING
# 4  diptanu/fBERT            test           109483778  ZERO_SHOT_TESTING
#
#   hyperparams experiment_name time dataset_currently_testing  \
# 0          NA                   NA                   evalita
# 1          NA                   NA                  ibereval
# 2          NA                   NA         hateval-immigrant
# 3          NA                   NA                  davidson
# 4          NA                   NA        founta_hateful_57k
#
#   dataset_currently_training dataset_wrt_training_datasets  ...  f1_score  \
# 0                         NA                     zero_shot  ...  0.304348
# 1                         NA                     zero_shot  ...  0.875000
# 2                         NA                     zero_shot  ...  0.435294
# 3                         NA                     zero_shot  ...  0.619048
# 4                         NA                     zero_shot  ...  0.816092
#
#   precision_score recall_score accuracy HATE_f1_score HATE_precision_score  \
# 0        0.218750     0.500000   0.4375      0.608696             0.437500
# 1        0.875000     0.875000   0.8750      0.875000             0.875000
# 2        0.536364     0.541667   0.4375      0.470588             0.800000
# 3        0.650794     0.672727   0.6250      0.571429             0.444444
# 4        0.966667     0.750000   0.9375      0.666667             1.000000
#
#    HATE_recall_score  NoHATE_f1_score  NoHATE_precision_score  \
# 0           1.000000         0.000000                0.000000
# 1           0.875000         0.875000                0.875000
# 2           0.333333         0.400000                0.272727
# 3           0.800000         0.666667                0.857143
# 4           0.500000         0.965517                0.933333
#
#    NoHATE_recall_score
# 0             0.000000
# 1             0.875000
# 2             0.750000
# 3             0.545455
# 4             1.000000
#
# [5 rows x 26 columns]

# %%
df
# Out:
#                       model type_experiment  n_trainable_params  \
# 0             diptanu/fBERT            test           109483778
# 1             diptanu/fBERT            test           109483778
# 2             diptanu/fBERT            test           109483778
# 3             diptanu/fBERT            test           109483778
# 4             diptanu/fBERT            test           109483778
# 5             diptanu/fBERT            test           109483778
# 6             diptanu/fBERT            test           109483778
# 7             diptanu/fBERT            test           109483778
# 8           GroNLP/hateBERT            test           109483778
# 9           GroNLP/hateBERT            test           109483778
# 10          GroNLP/hateBERT            test           109483778
# 11          GroNLP/hateBERT            test           109483778
# 12          GroNLP/hateBERT            test           109483778
# 13          GroNLP/hateBERT            test           109483778
# 14          GroNLP/hateBERT            test           109483778
# 15          GroNLP/hateBERT            test           109483778
# 16  FacebookAI/roberta-base            test           124647170
# 17  FacebookAI/roberta-base            test           124647170
# 18  FacebookAI/roberta-base            test           124647170
# 19  FacebookAI/roberta-base            test           124647170
# 20  FacebookAI/roberta-base            test           124647170
# 21  FacebookAI/roberta-base            test           124647170
# 22  FacebookAI/roberta-base            test           124647170
# 23  FacebookAI/roberta-base            test           124647170
#
#          cl_technique hyperparams experiment_name time  \
# 0   ZERO_SHOT_TESTING          NA                   NA
# 1   ZERO_SHOT_TESTING          NA                   NA
# 2   ZERO_SHOT_TESTING          NA                   NA
# 3   ZERO_SHOT_TESTING          NA                   NA
# 4   ZERO_SHOT_TESTING          NA                   NA
# 5   ZERO_SHOT_TESTING          NA                   NA
# 6   ZERO_SHOT_TESTING          NA                   NA
# 7   ZERO_SHOT_TESTING          NA                   NA
# 8   ZERO_SHOT_TESTING          NA                   NA
# 9   ZERO_SHOT_TESTING          NA                   NA
# 10  ZERO_SHOT_TESTING          NA                   NA
# 11  ZERO_SHOT_TESTING          NA                   NA
# 12  ZERO_SHOT_TESTING          NA                   NA
# 13  ZERO_SHOT_TESTING          NA                   NA
# 14  ZERO_SHOT_TESTING          NA                   NA
# 15  ZERO_SHOT_TESTING          NA                   NA
# 16  ZERO_SHOT_TESTING          NA                   NA
# 17  ZERO_SHOT_TESTING          NA                   NA
# 18  ZERO_SHOT_TESTING          NA                   NA
# 19  ZERO_SHOT_TESTING          NA                   NA
# 20  ZERO_SHOT_TESTING          NA                   NA
# 21  ZERO_SHOT_TESTING          NA                   NA
# 22  ZERO_SHOT_TESTING          NA                   NA
# 23  ZERO_SHOT_TESTING          NA                   NA
#
#    dataset_currently_testing dataset_currently_training  \
# 0                    evalita                         NA
# 1                   ibereval                         NA
# 2          hateval-immigrant                         NA
# 3                   davidson                         NA
# 4         founta_hateful_57k                         NA
# 5              hateval-women                         NA
# 6              waseem-racism                         NA
# 7              waseem-sexism                         NA
# 8                    evalita                         NA
# 9                   ibereval                         NA
# 10         hateval-immigrant                         NA
# 11                  davidson                         NA
# 12        founta_hateful_57k                         NA
# 13             hateval-women                         NA
# 14             waseem-racism                         NA
# 15             waseem-sexism                         NA
# 16                   evalita                         NA
# 17                  ibereval                         NA
# 18         hateval-immigrant                         NA
# 19                  davidson                         NA
# 20        founta_hateful_57k                         NA
# 21             hateval-women                         NA
# 22             waseem-racism                         NA
# 23             waseem-sexism                         NA
#
#    dataset_wrt_training_datasets  ...  f1_score precision_score recall_score  \
# 0                      zero_shot  ...  0.304348        0.218750     0.500000
# 1                      zero_shot  ...  0.875000        0.875000     0.875000
# 2                      zero_shot  ...  0.435294        0.536364     0.541667
# 3                      zero_shot  ...  0.619048        0.650794     0.672727
# 4                      zero_shot  ...  0.816092        0.966667     0.750000
# 5                      zero_shot  ...  0.058824        0.500000     0.031250
# 6                      zero_shot  ...  0.542857        0.551282     0.541667
# 7                      zero_shot  ...  0.881481        0.964286     0.833333
# 8                      zero_shot  ...  0.458937        0.535714     0.515873
# 9                      zero_shot  ...  0.417004        0.427273     0.437500
# 10                     zero_shot  ...  0.435294        0.653846     0.625000
# 11                     zero_shot  ...  0.360000        0.321429     0.409091
# 12                     zero_shot  ...  0.407407        0.423077     0.392857
# 13                     zero_shot  ...  0.428571        0.500000     0.375000
# 14                     zero_shot  ...  0.304348        0.318182     0.291667
# 15                     zero_shot  ...  0.360000        0.375000     0.346154
# 16                     zero_shot  ...  0.304348        0.218750     0.500000
# 17                     zero_shot  ...  0.333333        0.250000     0.500000
# 18                     zero_shot  ...  0.428571        0.375000     0.500000
# 19                     zero_shot  ...  0.238095        0.156250     0.500000
# 20                     zero_shot  ...  0.111111        0.062500     0.500000
# 21                     zero_shot  ...  0.000000        0.000000     0.000000
# 22                     zero_shot  ...  0.200000        0.125000     0.500000
# 23                     zero_shot  ...  0.157895        0.093750     0.500000
#
#    accuracy HATE_f1_score HATE_precision_score  HATE_recall_score  \
# 0    0.4375      0.608696             0.437500           1.000000
# 1    0.8750      0.875000             0.875000           0.875000
# 2    0.4375      0.470588             0.800000           0.333333
# 3    0.6250      0.571429             0.444444           0.800000
# 4    0.9375      0.666667             1.000000           0.500000
# 5    0.0625      0.000000             0.000000           0.000000
# 6    0.6875      0.285714             0.333333           0.250000
# 7    0.9375      0.800000             1.000000           0.666667
# 8    0.5625      0.222222             0.500000           0.142857
# 9    0.4375      0.307692             0.400000           0.250000
# 10   0.4375      0.400000             1.000000           0.250000
# 11   0.5625      0.000000             0.000000           0.000000
# 12   0.6875      0.000000             0.000000           0.000000
# 13   0.7500      0.000000             0.000000           0.000000
# 14   0.4375      0.000000             0.000000           0.000000
# 15   0.5625      0.000000             0.000000           0.000000
# 16   0.4375      0.608696             0.437500           1.000000
# 17   0.5000      0.666667             0.500000           1.000000
# 18   0.7500      0.857143             0.750000           1.000000
# 19   0.3125      0.476190             0.312500           1.000000
# 20   0.1250      0.222222             0.125000           1.000000
# 21   0.0000      0.000000             0.000000           0.000000
# 22   0.2500      0.400000             0.250000           1.000000
# 23   0.1875      0.315789             0.187500           1.000000
#
#     NoHATE_f1_score  NoHATE_precision_score  NoHATE_recall_score
# 0          0.000000                0.000000             0.000000
# 1          0.875000                0.875000             0.875000
# 2          0.400000                0.272727             0.750000
# 3          0.666667                0.857143             0.545455
# 4          0.965517                0.933333             1.000000
# 5          0.117647                1.000000             0.062500
# 6          0.800000                0.769231             0.833333
# 7          0.962963                0.928571             1.000000
# 8          0.695652                0.571429             0.888889
# 9          0.526316                0.454545             0.625000
# 10         0.470588                0.307692             1.000000
# 11         0.720000                0.642857             0.818182
# 12         0.814815                0.846154             0.785714
# 13         0.857143                1.000000             0.750000
# 14         0.608696                0.636364             0.583333
# 15         0.720000                0.750000             0.692308
# 16         0.000000                0.000000             0.000000
# 17         0.000000                0.000000             0.000000
# 18         0.000000                0.000000             0.000000
# 19         0.000000                0.000000             0.000000
# 20         0.000000                0.000000             0.000000
# 21         0.000000                0.000000             0.000000
# 22         0.000000                0.000000             0.000000
# 23         0.000000                0.000000             0.000000
#
# [24 rows x 26 columns]

# %%
df["type_experiment"].unique()
# Out:
# array(['test'], dtype=object)

# %%
df.to_csv("df_plm_zero_shots.csv", index=False)
